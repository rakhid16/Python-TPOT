# %% [markdown]
# Berikut adalah langkah-langkah dalam menggunakan TPOT untuk mencari algoritma pembelajaran mesin beserta parameternya.

# %% [markdown]
# ## 1. Impor modul

# %%
from tpot import TPOTRegressor
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np

# %% [markdown]
# <i>Library</i>/modul yang dibutuhkan cuma empat aja nih, yaitu :<br>
# 1 TPOT => Buat nyari algoritma pembelajaran mesih & parameter yang paling optimal.<br>
# 2 sklearn => Untuk memisah(membagi) <i>dataset</i> menjadi data latih dan data uji.<br>
# 3 Pandas => Buat memuat <i>dataset</i>.<br>
# 4 NumPy => Untuk menjadikan label yang ingin diprediksi menjadi <i>array</i> satu dimensi.

# %% [markdown]
# ## 2. Muat <i>dataset</i>

# %%
data = pd.read_csv('yacht_hydrodynamics.csv')
data
# Out:
#      longitudinal_pos  prismatic_coef  length_displac  beam_draught ratio  \
# 0                -2.3           0.568            4.78                3.99
# 1                -2.3           0.568            4.78                3.99
# 2                -2.3           0.568            4.78                3.99
# 3                -2.3           0.568            4.78                3.99
# 4                -2.3           0.568            4.78                3.99
# 5                -2.3           0.568            4.78                3.99
# 6                -2.3           0.568            4.78                3.99
# 7                -2.3           0.568            4.78                3.99
# 8                -2.3           0.568            4.78                3.99
# 9                -2.3           0.568            4.78                3.99
# 10               -2.3           0.568            4.78                3.99
# 11               -2.3           0.568            4.78                3.99
# 12               -2.3           0.568            4.78                3.99
# 13               -2.3           0.568            4.78                3.99
# 14               -2.3           0.569            4.78                3.04
# 15               -2.3           0.569            4.78                3.04
# 16               -2.3           0.569            4.78                3.04
# 17               -2.3           0.569            4.78                3.04
# 18               -2.3           0.569            4.78                3.04
# 19               -2.3           0.569            4.78                3.04
# 20               -2.3           0.569            4.78                3.04
# 21               -2.3           0.569            4.78                3.04
# 22               -2.3           0.569            4.78                3.04
# 23               -2.3           0.569            4.78                3.04
# 24               -2.3           0.569            4.78                3.04
# 25               -2.3           0.569            4.78                3.04
# 26               -2.3           0.569            4.78                3.04
# 27               -2.3           0.569            4.78                3.04
# 28               -2.3           0.565            4.78                5.35
# 29               -2.3           0.565            4.78                5.35
# ..                ...             ...             ...                 ...
# 278              -5.0           0.530            4.78                3.75
# 279              -5.0           0.530            4.78                3.75
# 280              -2.3           0.600            5.10                4.17
# 281              -2.3           0.600            5.10                4.17
# 282              -2.3           0.600            5.10                4.17
# 283              -2.3           0.600            5.10                4.17
# 284              -2.3           0.600            5.10                4.17
# 285              -2.3           0.600            5.10                4.17
# 286              -2.3           0.600            5.10                4.17
# 287              -2.3           0.600            5.10                4.17
# 288              -2.3           0.600            5.10                4.17
# 289              -2.3           0.600            5.10                4.17
# 290              -2.3           0.600            5.10                4.17
# 291              -2.3           0.600            5.10                4.17
# 292              -2.3           0.600            5.10                4.17
# 293              -2.3           0.600            5.10                4.17
# 294              -2.3           0.600            4.34                4.23
# 295              -2.3           0.600            4.34                4.23
# 296              -2.3           0.600            4.34                4.23
# 297              -2.3           0.600            4.34                4.23
# 298              -2.3           0.600            4.34                4.23
# 299              -2.3           0.600            4.34                4.23
# 300              -2.3           0.600            4.34                4.23
# 301              -2.3           0.600            4.34                4.23
# 302              -2.3           0.600            4.34                4.23
# 303              -2.3           0.600            4.34                4.23
# 304              -2.3           0.600            4.34                4.23
# 305              -2.3           0.600            4.34                4.23
# 306              -2.3           0.600            4.34                4.23
# 307              -2.3           0.600            4.34                4.23
#
#      length_beam ratio  froude num  residuary
# 0                 3.17       0.125       0.11
# 1                 3.17       0.150       0.27
# 2                 3.17       0.175       0.47
# 3                 3.17       0.200       0.78
# 4                 3.17       0.225       1.18
# 5                 3.17       0.250       1.82
# 6                 3.17       0.275       2.61
# 7                 3.17       0.300       3.76
# 8                 3.17       0.325       4.99
# 9                 3.17       0.350       7.16
# 10                3.17       0.375      11.93
# 11                3.17       0.400      20.11
# 12                3.17       0.425      32.75
# 13                3.17       0.450      49.49
# 14                3.64       0.125       0.04
# 15                3.64       0.150       0.17
# 16                3.64       0.175       0.37
# 17                3.64       0.200       0.66
# 18                3.64       0.225       1.06
# 19                3.64       0.250       1.59
# 20                3.64       0.275       2.33
# 21                3.64       0.300       3.29
# 22                3.64       0.325       4.61
# 23                3.64       0.350       7.11
# 24                3.64       0.375      11.99
# 25                3.64       0.400      21.09
# 26                3.64       0.425      35.01
# 27                3.64       0.450      51.80
# 28                2.76       0.125       0.09
# 29                2.76       0.150       0.29
# ..                 ...         ...        ...
# 278               3.15       0.425      37.14
# 279               3.15       0.450      55.87
# 280               3.51       0.125       0.01
# 281               3.51       0.150       0.16
# 282               3.51       0.175       0.39
# 283               3.51       0.200       0.73
# 284               3.51       0.225       1.24
# 285               3.51       0.250       1.96
# 286               3.51       0.275       3.04
# 287               3.51       0.300       4.46
# 288               3.51       0.325       6.31
# 289               3.51       0.350       8.68
# 290               3.51       0.375      12.39
# 291               3.51       0.400      20.14
# 292               3.51       0.425      31.77
# 293               3.51       0.450      47.13
# 294               2.73       0.125       0.04
# 295               2.73       0.150       0.17
# 296               2.73       0.175       0.36
# 297               2.73       0.200       0.64
# 298               2.73       0.225       1.02
# 299               2.73       0.250       1.62
# 300               2.73       0.275       2.63
# 301               2.73       0.300       4.15
# 302               2.73       0.325       6.00
# 303               2.73       0.350       8.47
# 304               2.73       0.375      12.27
# 305               2.73       0.400      19.59
# 306               2.73       0.425      30.48
# 307               2.73       0.450      46.66
#
# [308 rows x 7 columns]

# %% [markdown]
# Data yang kita pake itu data hidrodinamika kapal pesiar. (<i>nah lo</i>)<br>
# Klik link ini kalo kalian pengen tau lebih lanjut mengenai <i>dataset</i>'nya :<br>
# https://archive.ics.uci.edu/ml/datasets/Yacht+Hydrodynamics

# %% [markdown]
# ## 3. Bagi <i>dataset'nya</i>

# %% [markdown]
# Karena <i>dataset</i>  kita cuma satu jadinya kudu dibagi.<br>
# Berapa persen yang dijadiin data uji sama berapa persen sisanya yang kudu dijadiin data latih.

# %%
X_train, X_test, y_train, y_test = train_test_split(data, data['residuary'].ravel(),train_size=0.7, test_size=0.3)

# %% [markdown]
# X_train => seluruh data kita.<br>
# X_test => data yang berada di kolom <b>residuary</b>.<br>
# y_train => 70% dari jumlah keseluruhan data.<br>
# y_test => 30% dari jumlah keseluruhan data.

# %% [markdown]
# ## 4. Cari algoritma dan parameter'nya

# %% [markdown]
# Pada bagian inilah si TPOT beraksi.<br>
# Normalnya dari generasi ke generasi nilai <a href="https://id.wikipedia.org/wiki/Validasi-_Silang_(statistik)"><i>cross validation</i></a>'nya itu semakin membaik.

# %%
tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2)
tpot.fit(X_train, y_train)
# Out:
# Warning: xgboost.XGBRegressor is not available and will not be used by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=300, style=ProgressStyle(descript…
# Generation 1 - Current best internal CV score: -4.7673842852389327e-29
# Generation 2 - Current best internal CV score: -4.7673842852389327e-29
# Generation 3 - Current best internal CV score: -4.1358851322341865e-29
# Generation 4 - Current best internal CV score: -3.5543171952759125e-29
# Generation 5 - Current best internal CV score: -3.5543171952759125e-29
#
# Best pipeline: LassoLarsCV(FeatureAgglomeration(VarianceThreshold(input_matrix, threshold=0.05), affinity=manhattan, linkage=average), normalize=True)
# TPOTRegressor(config_dict=None, crossover_rate=0.1, cv=5,
#        disable_update_check=False, early_stop=None, generations=5,
#        max_eval_time_mins=5, max_time_mins=None, memory=None,
#        mutation_rate=0.9, n_jobs=1, offspring_size=None,
#        periodic_checkpoint_folder=None, population_size=50,
#        random_state=None, scoring=None, subsample=1.0, use_dask=False,
#        verbosity=2, warm_start=False)

# %% [markdown]
# Nah sudah ketahuan kan sekarang algortima dan parameter apa yang cocok sama <i>dataset</i> tersebut.<br>
# Ingat <b>banyaknya data berbanding lurus dengan lamanya proses iterasi</b>.

# %% [markdown]
# ## 5. Cek akurasi

# %% [markdown]
# Kalo kita mau tau berapa persen akurasi algoritma yang dipilihin sama TPOT tinggal ketik aja ini :

# %%
print(tpot.score(X_test, y_test))
# Out:
# -3.486192733932596e-29

# %% [markdown]
# Pada klasifikasi akurasi tertinggi adalah 100%/1.0 sedangkan pada regresi/prediksi akurasi tertinggi itu ketika nilai dari suatu galat sangat kecil(mendekati 0). Nilai ini dapat dicari dengan menggunakan rumus <a href="https://en.wikipedia.org/wiki/Mean_squared_error"><i>Mean squred error</i></a>.

# %% [markdown]
# ## 6. Ekspor <i>pipeline</i>

# %%
tpot.export("regressor.py")
# Out:
# True

# %% [markdown]
# hasil ekspor'nya bisa di lihat di <a href="https://github.com/Rakhid16/Python-TPOT/blob/master/regressor.py">sini</a> ya!<br>
# Sekian dari saya, semoga bermanfaat! :)
